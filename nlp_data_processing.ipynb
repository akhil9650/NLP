# %% [markdown]
# <a href="https://colab.research.google.com/github/akhil9650/NLP/blob/main/nlp_data_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import csv

# %%
dataset = pd.read_csv('/content/drive/My Drive/Colab Notebooks/skillege.csv')

# %%
dataset = dataset[:-1400000]

# %%
dataset.describe()
# Out:
#          Unnamed: 0
# count  90268.000000
# mean   45133.500000
# std    26058.271387
# min        0.000000
# 25%    22566.750000
# 50%    45133.500000
# 75%    67700.250000
# max    90267.000000

# %%
dataset.to_csv('/content/drive/My Drive/Colab Notebooks/skillege.csv')

# %%
dda = pd.read_csv('/content/drive/My Drive/Colab Notebooks/small_skill.csv')

# %%
dda.describe()
# Out:
#        Unnamed: 0  Unnamed: 0.1
# count  268.000000    268.000000
# mean   133.500000    133.500000
# std     77.509139     77.509139
# min      0.000000      0.000000
# 25%     66.750000     66.750000
# 50%    133.500000    133.500000
# 75%    200.250000    200.250000
# max    267.000000    267.000000

# %%
reader = csv.reader(open('/content/drive/My Drive/Colab Notebooks/small_skill.csv', 'r'))
d = []
count = 0

# %%
d = []

# %%
d = dataset.iloc[:, 1]

# %%
count
# Out:
# 269

# %%
d
# Out:
# 0      ['Key Account Development', 'Strategic Plannin...
# 1                    ['Molecular Biology', 'Biomarkers']
# 2      ['DNA', 'Nanotechnology', 'Molecular Biology',...
# 3      ['Program Management', 'French', 'Avionics', '...
# 4      ['Digital Strategy', 'Integrated Marketing', '...
# 5      ['DLP', 'Managed Services', 'Solution Selling'...
# 6      ['Project Management', 'Cross-functional Team ...
# 7      ['Predictive Analytics', 'Business Analysis', ...
# 8      ['virtual team', 'Project Management', 'Projec...
# 9      ['Recruiting', 'HR Consulting', 'Outplacement'...
# 10     ['Interactive Marketing', 'Content Strategy', ...
# 11     ['Social Media', 'Email Marketing', 'Shopper M...
# 12     ['AML', 'Relationship Management', 'Team Manag...
# 13     ['Microbiology', 'Vaccines', 'International Sa...
# 14     ['Primavera', 'Revit MEP', 'AutoCAD', 'Enginee...
# 15     ['Six Sigma', 'Quality Management', 'Manufactu...
# ...

# %%
dda = dda.replace(' ', '_', regex=True)

# %%
dda
# Out:
#      Unnamed: 0  ...                                              Skill
# 0             0  ...  ['Key_Account_Development',_'Strategic_Plannin...
# 1             1  ...                ['Molecular_Biology',_'Biomarkers']
# 2             2  ...  ['DNA',_'Nanotechnology',_'Molecular_Biology',...
# 3             3  ...  ['Program_Management',_'French',_'Avionics',_'...
# 4             4  ...  ['Digital_Strategy',_'Integrated_Marketing',_'...
# 5             5  ...  ['DLP',_'Managed_Services',_'Solution_Selling'...
# 6             6  ...  ['Project_Management',_'Cross-functional_Team_...
# 7             7  ...  ['Predictive_Analytics',_'Business_Analysis',_...
# 8             8  ...  ['virtual_team',_'Project_Management',_'Projec...
# 9             9  ...  ['Recruiting',_'HR_Consulting',_'Outplacement'...
# 10           10  ...  ['Interactive_Marketing',_'Content_Strategy',_...
# 11           11  ...  ['Social_Media',_'Email_Marketing',_'Shopper_M...
# ...

# %%
dda = dda.replace(',_', ',', regex=True)

# %%
dda
# Out:
#      Unnamed: 0  ...                                              Skill
# 0             0  ...  ['Key_Account_Development','Strategic_Planning...
# 1             1  ...                 ['Molecular_Biology','Biomarkers']
# 2             2  ...  ['DNA','Nanotechnology','Molecular_Biology','S...
# 3             3  ...  ['Program_Management','French','Avionics','Emb...
# 4             4  ...  ['Digital_Strategy','Integrated_Marketing','Di...
# 5             5  ...  ['DLP','Managed_Services','Solution_Selling','...
# 6             6  ...  ['Project_Management','Cross-functional_Team_L...
# 7             7  ...  ['Predictive_Analytics','Business_Analysis','C...
# 8             8  ...  ['virtual_team','Project_Management','Project_...
# 9             9  ...  ['Recruiting','HR_Consulting','Outplacement','...
# 10           10  ...  ['Interactive_Marketing','Content_Strategy','A...
# 11           11  ...  ['Social_Media','Email_Marketing','Shopper_Mar...
# ...

# %%
corpus_text = '\n'.join(dda[:268]['Skill'])
sentences = corpus_text.split('\n')
sentences = [line.lower().split(',') for line in sentences]

# %%
sentences[1]
# Out:
# ["['molecular_biology'", "'biomarkers']"]
